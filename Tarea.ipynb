# %% [markdown]
# <a href="https://colab.research.google.com/github/August13CMD/Diplomado/blob/main/Tarea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\Drive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
nf=pd.read_excel("tote_shipment.xlsx")
nf
# Out:
#        asset_type  asset_id                           tag_id   Site  \
# 0            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4            tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...           ...       ...                              ...    ...
# 130056       tote       205  (01)00850027865010(21)0082T1137  Store
# 130057       tote       205  (01)00850027865010(21)0082T1137  Store
# 130058       tote       205  (01)00850027865010(21)0082T1137  Store
# 130059       tote       205  (01)00850027865010(21)0082T1137  Store
# 130060       tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zone     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# ...

# %% [markdown]
# RESPUESTA A LA PREGUNTA 1, INCISO 1

# %%
nf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130061 entries, 0 to 130060
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   asset_type     130061 non-null  object
#  1   asset_id       130061 non-null  int64
#  2   tag_id         130061 non-null  object
#  3   Site           130061 non-null  object
#  4   Zone           130061 non-null  object
#  5   device_id      130061 non-null  object
#  6   time_est       130061 non-null  datetime64[ns]
#  7   lat            130061 non-null  float64
#  8   lng            130061 non-null  float64
#  9   Temperature_C  130061 non-null  float64
#  10  Temperature_F  130061 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 10.9+ MB

# %% [markdown]
# RESPUESTA A LA PREGUNTA 1, INCISO 2

# %%
nf["Zone"].unique()
# Out:
# array(['dock_doors_DC1', 'dock_doors_DC2', 'Forklift3_DC1',
#        'pallet_assembly_DC1', 'PhoneKit1Bridge', 'PhoneKit2Bridge',
#        'PhoneKit2GW', 'point_of_sale_Store', 'receiving_Store',
#        'staging_DC1', 'staging_DC2', 'store_back_Store',
#        'store_front_Store', 'Forklift1_DC1', 'PhoneKit1GW'], dtype=object)

# %% [markdown]
# RESPUESTA A LA PREGUNTA 2, INCISO 1

# %%
nf["Temperature_C"].min()
# Out:
# 19.0

# %%
nf["Temperature_C"].max()
# Out:
# 44.0

# %%
nf["Temperature_F"].min()
# Out:
# 66.2

# %%
nf["Temperature_F"].max()
# Out:
# 111.2

# %% [markdown]
# RESPUESTA A LA PREGUNTA 2, INCISO 2

# %%
pd.DataFrame(nf.groupby(['Site'])['Temperature_C'].unique()).reset_index()
# Out:
#       Site                                      Temperature_C
# 0     DC 1  [23.0, 23.5, 24.5, 22.5, 22.75, 24.0, 23.75, 2...
# 1     DC 2  [25.0, 24.5, 25.5, 24.0, 23.5, 26.0, 25.63, 25...
# 2    Store  [24.5, 21.0, 22.5, 24.0, 22.0, 25.0, 24.83, 24...
# 3  Transit  [24.5, 25.5, 26.0, 26.5, 24.0, 25.0, 27.0, 23....

# %%
filt =nf[nf.Temperature_C==nf["Temperature_C"].min()]
filt
# Out:
#       asset_type  asset_id                           tag_id   Site  \
# 92279       tote       159  (01)00850027865010(21)0082T0197  Store
#
#                    Zone     device_id                time_est       lat  \
# 92279  store_back_Store  08D0A74A7C1D 2022-08-04 21:17:51.079  47.74923
#
#             lng  Temperature_C  Temperature_F
# 92279 -65.64101           19.0           66.2

# %%
filt =nf[nf.Temperature_C==nf["Temperature_C"].min()]
filt['Site']
# Out:
# 92279    Store
# Name: Site, dtype: object

# %%
fil =nf[nf.Temperature_C==nf["Temperature_C"].max()]
fil
# Out:
#       asset_type  asset_id                           tag_id   Site  \
# 57195       tote        70  (01)00850027865010(21)0082T0415  Store
# 57196       tote        70  (01)00850027865010(21)0082T0415  Store
# 57197       tote        70  (01)00850027865010(21)0082T0415  Store
# 57199       tote        70  (01)00850027865010(21)0082T0415  Store
# 59985       tote        70  (01)00850027865010(21)0082T0415  Store
#
#                    Zone     device_id                time_est       lat  \
# 57195   receiving_Store  AC8DEAE6FD79 2022-08-04 09:53:28.320  47.74923
# 57196   receiving_Store  DC4FBAED57C9 2022-08-04 09:54:25.207  47.74923
# 57197   receiving_Store  DC4FBAED57C9 2022-08-04 09:54:53.887  47.74923
# 57199   receiving_Store  AC8DEAE6FD79 2022-08-04 09:57:24.778  47.74923
# 59985  store_back_Store  58DB59BDCE08 2022-08-04 09:55:54.070  47.74923
#
#             lng  Temperature_C  Temperature_F
# 57195 -65.64101           44.0          111.2
# ...

# %% [markdown]
# RESPUESTA A LA PREGUNTA 3 PARA EL CASO ESPECIFICO DE asset_id = 37

# %%
import plotly.express as px

# %%
import plotly.io as pio

# %%
nbd=nf[nf.asset_id == 37]
nbd
# Out:
#       asset_type  asset_id                           tag_id   Site  \
# 6769        tote        37  (01)00850027865010(21)0082T0017   DC 1
# 6770        tote        37  (01)00850027865010(21)0082T0953   DC 1
# 6771        tote        37  (01)00850027865010(21)0082T0017   DC 2
# 6772        tote        37  (01)00850027865010(21)0082T0017   DC 2
# 6773        tote        37  (01)00850027865010(21)0082T0017   DC 2
# ...          ...       ...                              ...    ...
# 19605       tote        37  (01)00850027865010(21)0082T0953  Store
# 19606       tote        37  (01)00850027865010(21)0082T0953  Store
# 19607       tote        37  (01)00850027865010(21)0082T0953  Store
# 19608       tote        37  (01)00850027865010(21)0082T0953  Store
# 19609       tote        37  (01)00850027865010(21)0082T0953  Store
#
#                     Zone     device_id                time_est        lat  \
# 6769      dock_doors_DC1  EC5B0499234F 2022-08-02 12:00:24.040  47.792960
# ...

# %% [markdown]
# RESPUESTA A LA PREGUNTA 3 PARA EL CASO ESPECIFICO DE asset_id = 37

# %%
fig = px.scatter(nbd, x = 'Zone', y = 'time_est')
fig.update_layout(
    xaxis_title = 'ZONE',
    yaxis_title = 'TIME ESTIMETED',
    template = 'plotly_white',
    ) 
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# RESPUESTA A LA PREGUNTA 4 PARA EL CASO ESPECIFICO DE asset_id = 37

# %%
fig = px.scatter(nbd, x = 'Temperature_C', y = 'time_est')
fig.update_layout(
    xaxis_title = 'TEMPERATURE',
    yaxis_title = 'TIME ESTIMETED',
    template = 'plotly_white',
    ) 
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# RESPUESTA A LA PREGUNTA 5

# %%
fig = px.scatter(nbd, x = 'lat', y = 'lng')
fig.update_layout(
    xaxis_title = 'latitud',
    yaxis_title = 'longitud',
    template = 'plotly_white',
    ) 
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# RESPUESTA A LA PREGUNTA 6
